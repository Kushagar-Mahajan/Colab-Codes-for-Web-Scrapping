# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushagar-Mahajan/Colab-Codes/blob/master/Basic_Python_and_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=[2,9,7,3]
y=[7,5,3,6]

plt.xlabel("Distance")  #x axis
plt.ylabel("Time")  #y axis
plt.plot(x,y,color='black',label='railway track')   #it will draw a graph
plt.scatter(x,y,s=200,color="red",label='railway station',marker='*') #it will plot dots 
plt.bar(x,y,label='height of railway station') #to plot bar charts
plt.grid(color='green') #will draw a grid
plt.legend() #it will show label in plot
plt.show()  #will draw graph

# %%
#this will be another example of cricket data visualization
players=['Sachin','Dhoni','Virat','Rohit']
scores=[200,140,150,269]

plt.xlabel('players')
plt.ylabel('scores')
#plt.bar(players,scores,label="2020 score of Indian Cricket Team")
plt.pie(scores,labels=players,explode=(0.2,0,0,0),shadow=True,autopct='%1.1f%%') #plot pie chart, explode is for differnt representation
#plt.grid(color='green')
#plt.legend()
plt.show()
